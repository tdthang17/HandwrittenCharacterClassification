# %%
# IMPORTANT: RUN THIS CELL IN ORDER TO IMPORT YOUR KAGGLE DATA SOURCES,
# THEN FEEL FREE TO DELETE THIS CELL.
# NOTE: THIS NOTEBOOK ENVIRONMENT DIFFERS FROM KAGGLE'S PYTHON
# ENVIRONMENT SO THERE MAY BE MISSING LIBRARIES USED BY YOUR
# NOTEBOOK.
import kagglehub
sujaymann_handwritten_english_characters_and_digits_path = kagglehub.dataset_download('sujaymann/handwritten-english-characters-and-digits')

print('Data source import complete.')

# %% [markdown]
# ## Import Libraries

# %%
import numpy as np
import pandas as pd
import tensorflow
from tensorflow import keras
from keras.models import Sequential
from keras.layers import Input,Flatten,Dense,Dropout
from keras.applications.vgg19 import VGG19
from keras.preprocessing import image_dataset_from_directory
from sklearn.metrics import confusion_matrix
import matplotlib.pyplot as plt
import string
import seaborn as sns
import os

print(np.__version__)
print(pd.__version__)
print(tensorflow.__version__)
print(keras.__version__)
# Out:
# 2025-06-13 02:14:24.626585: E external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:9261] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2025-06-13 02:14:24.626695: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:607] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2025-06-13 02:14:24.761518: E external/local_xla/xla/stream_executor/cuda/cuda_blas.cc:1515] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 1.26.4
# 2.2.2
# 2.15.0
# 3.4.1

# %% [markdown]
# ## Create training and testing datasets from directories

# %%
train_ds = image_dataset_from_directory(
    directory = '/kaggle/input/handwritten-english-characters-and-digits/augmented_images/augmented_images1',
    labels = 'inferred',
    label_mode = 'int',
    image_size = (224, 224),
    shuffle = True
)

test_ds1 = image_dataset_from_directory(
    directory = '/kaggle/input/handwritten-english-characters-and-digits/handwritten-english-characters-and-digits/combined_folder/train',
    labels = 'inferred',
    label_mode = 'int',
    image_size = (224, 224)
)

test_ds2 = image_dataset_from_directory(
    directory = '/kaggle/input/handwritten-english-characters-and-digits/handwritten-english-characters-and-digits/combined_folder/test',
    labels = 'inferred',
    label_mode = 'int',
    image_size = (224, 224)
)

test_ds = test_ds1.concatenate(test_ds2)
# Out:
# Found 13640 files belonging to 62 classes.
# Found 2728 files belonging to 62 classes.
# Found 682 files belonging to 62 classes.

# %%
image, label = next(iter(train_ds))
plt.imshow(image[0])

# %% [markdown]
# ## Normalize Image Values

# %%
train_ds_norm = train_ds.map(lambda x, y: (x / 255.0, y))
test_ds_norm = test_ds.map(lambda x, y: (x / 255.0, y))

# %%
image, label = next(iter(train_ds_norm))
plt.imshow(image[0])

# %%
len(train_ds)
# Out:
# 427

# %%
len(test_ds)
# Out:
# 108

# %% [markdown]
# ## Splitting data into train and val set

# %%
train_size = int(0.8 * len(train_ds_norm))
print(train_size)
val_ds_norm = train_ds_norm.skip(train_size)
train_ds_norm = train_ds_norm.take(train_size)
# Out:
# 341

# %%
len(train_ds_norm)
# Out:
# 341

# %%
len(val_ds_norm)
# Out:
# 86

# %% [markdown]
# ## VGG19 Model for Transfer Learning

# %%
conv_base = VGG19(
    weights = 'imagenet',
    include_top = False,
    input_shape = (224, 224, 3)
)
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/vgg19/vgg19_weights_tf_dim_ordering_tf_kernels_notop.h5
# 80134624/80134624 ━━━━━━━━━━━━━━━━━━━━ 0s 0us/step

# %% [markdown]
# ### Freeze weights

# %%
conv_base.trainable = False

# %%
conv_base.summary()
# Out:
# Model: "vgg19"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ input_layer (InputLayer)        │ (None, 224, 224, 3)    │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ block1_conv1 (Conv2D)           │ (None, 224, 224, 64)   │         1,792 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ block1_conv2 (Conv2D)           │ (None, 224, 224, 64)   │        36,928 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ block1_pool (MaxPooling2D)      │ (None, 112, 112, 64)   │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ block2_conv1 (Conv2D)           │ (None, 112, 112, 128)  │        73,856 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ block2_conv2 (Conv2D)           │ (None, 112, 112, 128)  │       147,584 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ block2_pool (MaxPooling2D)      │ (None, 56, 56, 128)    │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ block3_conv1 (Conv2D)           │ (None, 56, 56, 256)    │       295,168 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ block3_conv2 (Conv2D)           │ (None, 56, 56, 256)    │       590,080 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ block3_conv3 (Conv2D)           │ (None, 56, 56, 256)    │       590,080 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ block3_conv4 (Conv2D)           │ (None, 56, 56, 256)    │       590,080 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ block3_pool (MaxPooling2D)      │ (None, 28, 28, 256)    │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ block4_conv1 (Conv2D)           │ (None, 28, 28, 512)    │     1,180,160 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ block4_conv2 (Conv2D)           │ (None, 28, 28, 512)    │     2,359,808 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ block4_conv3 (Conv2D)           │ (None, 28, 28, 512)    │     2,359,808 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ block4_conv4 (Conv2D)           │ (None, 28, 28, 512)    │     2,359,808 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ block4_pool (MaxPooling2D)      │ (None, 14, 14, 512)    │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ block5_conv1 (Conv2D)           │ (None, 14, 14, 512)    │     2,359,808 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ block5_conv2 (Conv2D)           │ (None, 14, 14, 512)    │     2,359,808 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ block5_conv3 (Conv2D)           │ (None, 14, 14, 512)    │     2,359,808 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ block5_conv4 (Conv2D)           │ (None, 14, 14, 512)    │     2,359,808 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ block5_pool (MaxPooling2D)      │ (None, 7, 7, 512)      │             0 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 20,024,384 (76.39 MB)
#  Trainable params: 0 (0.00 B)
#  Non-trainable params: 20,024,384 (76.39 MB)

# %% [markdown]
# ## Add Fully Connected Layers

# %%
model = Sequential()
model.add(Input(shape=(224,224,3)))
model.add(conv_base)
model.add(Flatten())
model.add(Dense(224,activation='relu'))
model.add(Dropout(0.1))
model.add(Dense(416,activation='sigmoid'))
model.add(Dropout(0.1))
model.add(Dense(62,activation='softmax'))

# %%
model.summary()
# Out:
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ vgg19 (Functional)              │ (None, 7, 7, 512)      │    20,024,384 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ flatten (Flatten)               │ (None, 25088)          │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense (Dense)                   │ (None, 224)            │     5,619,936 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout (Dropout)               │ (None, 224)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_1 (Dense)                 │ (None, 416)            │        93,600 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_1 (Dropout)             │ (None, 416)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_2 (Dense)                 │ (None, 62)             │        25,854 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 25,763,774 (98.28 MB)
#  Trainable params: 5,739,390 (21.89 MB)
#  Non-trainable params: 20,024,384 (76.39 MB)

# %%
model.compile(loss='sparse_categorical_crossentropy',optimizer='sgd',metrics=['accuracy'])

# %% [markdown]
# ## Model Training

# %%
history = model.fit(train_ds_norm, epochs=50, validation_data=val_ds_norm)
# Out:
# Epoch 1/50
#   1/341 ━━━━━━━━━━━━━━━━━━━━ 3:16:57 35s/step - accuracy: 0.0312 - loss: 4.3036
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# I0000 00:00:1749781010.737891     120 device_compiler.h:186] Compiled cluster using XLA!  This line is logged at most once for the lifetime of the process.
# W0000 00:00:1749781010.752449     120 graph_launch.cc:671] Fallback to op-by-op mode because memset node breaks graph update
# 341/341 ━━━━━━━━━━━━━━━━━━━━ 0s 149ms/step - accuracy: 0.0194 - loss: 4.2093
# W0000 00:00:1749781091.993718     120 graph_launch.cc:671] Fallback to op-by-op mode because memset node breaks graph update
# 341/341 ━━━━━━━━━━━━━━━━━━━━ 140s 310ms/step - accuracy: 0.0194 - loss: 4.2092 - val_accuracy: 0.0469 - val_loss: 4.0631
# Epoch 2/50
# W0000 00:00:1749781116.100392     119 graph_launch.cc:671] Fallback to op-by-op mode because memset node breaks graph update
# 341/341 ━━━━━━━━━━━━━━━━━━━━ 97s 285ms/step - accuracy: 0.0358 - loss: 4.0611 - val_accuracy: 0.1004 - val_loss: 3.8944
# Epoch 3/50
# 341/341 ━━━━━━━━━━━━━━━━━━━━ 98s 286ms/step - accuracy: 0.0922 - loss: 3.8586 - val_accuracy: 0.2119 - val_loss: 3.5871
# Epoch 4/50
# 341/341 ━━━━━━━━━━━━━━━━━━━━ 98s 288ms/step - accuracy: 0.1611 - loss: 3.5487 - val_accuracy: 0.2672 - val_loss: 3.2493
# Epoch 5/50
# 341/341 ━━━━━━━━━━━━━━━━━━━━ 98s 286ms/step - accuracy: 0.2271 - loss: 3.2097 - val_accuracy: 0.3567 - val_loss: 2.9036
# Epoch 6/50
# 341/341 ━━━━━━━━━━━━━━━━━━━━ 98s 287ms/step - accuracy: 0.2959 - loss: 2.9032 - val_accuracy: 0.4205 - val_loss: 2.6345
# Epoch 7/50
# 341/341 ━━━━━━━━━━━━━━━━━━━━ 98s 288ms/step - accuracy: 0.3701 - loss: 2.6260 - val_accuracy: 0.4817 - val_loss: 2.3347
# Epoch 8/50
# 341/341 ━━━━━━━━━━━━━━━━━━━━ 98s 287ms/step - accuracy: 0.4240 - loss: 2.3839 - val_accuracy: 0.5040 - val_loss: 2.1530
# Epoch 9/50
# 341/341 ━━━━━━━━━━━━━━━━━━━━ 98s 287ms/step - accuracy: 0.4657 - loss: 2.1751 - val_accuracy: 0.5539 - val_loss: 1.9533
# Epoch 10/50
# 341/341 ━━━━━━━━━━━━━━━━━━━━ 98s 288ms/step - accuracy: 0.5121 - loss: 1.9971 - val_accuracy: 0.6037 - val_loss: 1.7576
# Epoch 11/50
# 341/341 ━━━━━━━━━━━━━━━━━━━━ 98s 286ms/step - accuracy: 0.5524 - loss: 1.8359 - val_accuracy: 0.6353 - val_loss: 1.6083
# Epoch 12/50
# 341/341 ━━━━━━━━━━━━━━━━━━━━ 98s 287ms/step - accuracy: 0.5746 - loss: 1.7094 - val_accuracy: 0.6246 - val_loss: 1.5500
# Epoch 13/50
# 341/341 ━━━━━━━━━━━━━━━━━━━━ 98s 286ms/step - accuracy: 0.5975 - loss: 1.5836 - val_accuracy: 0.6741 - val_loss: 1.3922
# Epoch 14/50
# 341/341 ━━━━━━━━━━━━━━━━━━━━ 98s 287ms/step - accuracy: 0.6180 - loss: 1.4808 - val_accuracy: 0.6694 - val_loss: 1.3505
# Epoch 15/50
# 341/341 ━━━━━━━━━━━━━━━━━━━━ 98s 287ms/step - accuracy: 0.6440 - loss: 1.3928 - val_accuracy: 0.6771 - val_loss: 1.2779
# Epoch 16/50
# 341/341 ━━━━━━━━━━━━━━━━━━━━ 98s 288ms/step - accuracy: 0.6602 - loss: 1.3315 - val_accuracy: 0.7001 - val_loss: 1.1805
# Epoch 17/50
# 341/341 ━━━━━━━━━━━━━━━━━━━━ 98s 287ms/step - accuracy: 0.6776 - loss: 1.2556 - val_accuracy: 0.6826 - val_loss: 1.1878
# Epoch 18/50
# 341/341 ━━━━━━━━━━━━━━━━━━━━ 98s 287ms/step - accuracy: 0.6855 - loss: 1.1997 - val_accuracy: 0.7350 - val_loss: 1.0790
# Epoch 19/50
# 341/341 ━━━━━━━━━━━━━━━━━━━━ 98s 287ms/step - accuracy: 0.7128 - loss: 1.1215 - val_accuracy: 0.7342 - val_loss: 1.0256
# Epoch 20/50
# 341/341 ━━━━━━━━━━━━━━━━━━━━ 98s 288ms/step - accuracy: 0.7122 - loss: 1.0950 - val_accuracy: 0.7361 - val_loss: 1.0098
# Epoch 21/50
# 341/341 ━━━━━━━━━━━━━━━━━━━━ 98s 287ms/step - accuracy: 0.7162 - loss: 1.0477 - val_accuracy: 0.7346 - val_loss: 0.9920
# Epoch 22/50
# 341/341 ━━━━━━━━━━━━━━━━━━━━ 98s 288ms/step - accuracy: 0.7275 - loss: 1.0067 - val_accuracy: 0.7474 - val_loss: 0.9754
# Epoch 23/50
# 341/341 ━━━━━━━━━━━━━━━━━━━━ 98s 287ms/step - accuracy: 0.7444 - loss: 0.9726 - val_accuracy: 0.7313 - val_loss: 0.9669
# Epoch 24/50
# 341/341 ━━━━━━━━━━━━━━━━━━━━ 97s 285ms/step - accuracy: 0.7416 - loss: 0.9382 - val_accuracy: 0.7617 - val_loss: 0.8873
# Epoch 25/50
# 341/341 ━━━━━━━━━━━━━━━━━━━━ 98s 288ms/step - accuracy: 0.7608 - loss: 0.8922 - val_accuracy: 0.7581 - val_loss: 0.8908
# Epoch 26/50
# 341/341 ━━━━━━━━━━━━━━━━━━━━ 98s 288ms/step - accuracy: 0.7609 - loss: 0.8811 - val_accuracy: 0.7507 - val_loss: 0.8977
# Epoch 27/50
# 341/341 ━━━━━━━━━━━━━━━━━━━━ 98s 287ms/step - accuracy: 0.7605 - loss: 0.8558 - val_accuracy: 0.7771 - val_loss: 0.8042
# Epoch 28/50
# 341/341 ━━━━━━━━━━━━━━━━━━━━ 98s 288ms/step - accuracy: 0.7766 - loss: 0.8232 - val_accuracy: 0.7694 - val_loss: 0.8098
# Epoch 29/50
# 341/341 ━━━━━━━━━━━━━━━━━━━━ 98s 288ms/step - accuracy: 0.7812 - loss: 0.8000 - val_accuracy: 0.7771 - val_loss: 0.8001
# Epoch 30/50
# 341/341 ━━━━━━━━━━━━━━━━━━━━ 142s 288ms/step - accuracy: 0.7867 - loss: 0.7639 - val_accuracy: 0.8057 - val_loss: 0.7348
# Epoch 31/50
# 341/341 ━━━━━━━━━━━━━━━━━━━━ 98s 287ms/step - accuracy: 0.7896 - loss: 0.7583 - val_accuracy: 0.7834 - val_loss: 0.7825
# Epoch 32/50
# 341/341 ━━━━━━━━━━━━━━━━━━━━ 98s 287ms/step - accuracy: 0.7928 - loss: 0.7392 - val_accuracy: 0.7984 - val_loss: 0.7149
# Epoch 33/50
# 341/341 ━━━━━━━━━━━━━━━━━━━━ 98s 287ms/step - accuracy: 0.8008 - loss: 0.7096 - val_accuracy: 0.7830 - val_loss: 0.7653
# Epoch 34/50
# 341/341 ━━━━━━━━━━━━━━━━━━━━ 98s 286ms/step - accuracy: 0.8019 - loss: 0.6967 - val_accuracy: 0.8043 - val_loss: 0.6887
# Epoch 35/50
# 341/341 ━━━━━━━━━━━━━━━━━━━━ 98s 286ms/step - accuracy: 0.8084 - loss: 0.6846 - val_accuracy: 0.8101 - val_loss: 0.6570
# Epoch 36/50
# 341/341 ━━━━━━━━━━━━━━━━━━━━ 97s 286ms/step - accuracy: 0.8137 - loss: 0.6641 - val_accuracy: 0.8105 - val_loss: 0.6646
# Epoch 37/50
# 341/341 ━━━━━━━━━━━━━━━━━━━━ 97s 285ms/step - accuracy: 0.8089 - loss: 0.6611 - val_accuracy: 0.7896 - val_loss: 0.6945
# Epoch 38/50
# 341/341 ━━━━━━━━━━━━━━━━━━━━ 98s 287ms/step - accuracy: 0.8170 - loss: 0.6390 - val_accuracy: 0.7775 - val_loss: 0.7610
# Epoch 39/50
# 341/341 ━━━━━━━━━━━━━━━━━━━━ 98s 288ms/step - accuracy: 0.8159 - loss: 0.6267 - val_accuracy: 0.7845 - val_loss: 0.7042
# Epoch 40/50
# 341/341 ━━━━━━━━━━━━━━━━━━━━ 98s 286ms/step - accuracy: 0.8205 - loss: 0.6178 - val_accuracy: 0.8281 - val_loss: 0.6147
# Epoch 41/50
# 341/341 ━━━━━━━━━━━━━━━━━━━━ 98s 287ms/step - accuracy: 0.8213 - loss: 0.6025 - val_accuracy: 0.8130 - val_loss: 0.6192
# Epoch 42/50
# 341/341 ━━━━━━━━━━━━━━━━━━━━ 98s 286ms/step - accuracy: 0.8313 - loss: 0.5870 - val_accuracy: 0.8130 - val_loss: 0.6263
# Epoch 43/50
# 341/341 ━━━━━━━━━━━━━━━━━━━━ 98s 286ms/step - accuracy: 0.8324 - loss: 0.5803 - val_accuracy: 0.8178 - val_loss: 0.6064
# Epoch 44/50
# 341/341 ━━━━━━━━━━━━━━━━━━━━ 98s 286ms/step - accuracy: 0.8371 - loss: 0.5614 - val_accuracy: 0.8339 - val_loss: 0.5544
# Epoch 45/50
# 341/341 ━━━━━━━━━━━━━━━━━━━━ 97s 286ms/step - accuracy: 0.8381 - loss: 0.5583 - val_accuracy: 0.8281 - val_loss: 0.5778
# Epoch 46/50
# 341/341 ━━━━━━━━━━━━━━━━━━━━ 98s 287ms/step - accuracy: 0.8400 - loss: 0.5440 - val_accuracy: 0.8277 - val_loss: 0.5693
# Epoch 47/50
# 341/341 ━━━━━━━━━━━━━━━━━━━━ 98s 286ms/step - accuracy: 0.8437 - loss: 0.5291 - val_accuracy: 0.8376 - val_loss: 0.5368
# Epoch 48/50
# 341/341 ━━━━━━━━━━━━━━━━━━━━ 98s 286ms/step - accuracy: 0.8476 - loss: 0.5214 - val_accuracy: 0.8255 - val_loss: 0.5751
# Epoch 49/50
# 341/341 ━━━━━━━━━━━━━━━━━━━━ 98s 287ms/step - accuracy: 0.8430 - loss: 0.5226 - val_accuracy: 0.8387 - val_loss: 0.5486
# Epoch 50/50
# 341/341 ━━━━━━━━━━━━━━━━━━━━ 98s 286ms/step - accuracy: 0.8511 - loss: 0.5000 - val_accuracy: 0.8424 - val_loss: 0.5276

# %% [markdown]
# ## Accuracy Curve

# %%
plt.plot(history.history['accuracy'], label='accuracy')
plt.plot(history.history['val_accuracy'], label='val_accuracy')
plt.legend()
plt.show()

# %% [markdown]
# ## Loss Curve

# %%
plt.plot(history.history['loss'], label='loss')
plt.plot(history.history['val_loss'], label='val_loss')
plt.legend()
plt.show()

# %% [markdown]
# ## Evaluation on training data

# %%
loss, accuracy = model.evaluate(train_ds_norm)
print("Loss:", loss)
print("Accuracy:", accuracy)
# Out:
# 341/341 ━━━━━━━━━━━━━━━━━━━━ 55s 160ms/step - accuracy: 0.8879 - loss: 0.4012
# Loss: 0.4062530994415283
# Accuracy: 0.883980929851532

# %% [markdown]
# ## Evaluation on testing data

# %%
loss, accuracy = model.evaluate(test_ds_norm)
print("Loss:", loss)
print("Accuracy:", accuracy)
# Out:
# 108/108 ━━━━━━━━━━━━━━━━━━━━ 17s 161ms/step - accuracy: 0.8976 - loss: 0.3416
# Loss: 0.3876709043979645
# Accuracy: 0.8841642141342163

# %% [markdown]
# ## Evaluation on validation data

# %%
loss, accuracy = model.evaluate(val_ds_norm)
print("Loss:", loss)
print("Accuracy:", accuracy)
# Out:
# 86/86 ━━━━━━━━━━━━━━━━━━━━ 42s 155ms/step - accuracy: 0.8508 - loss: 0.5250
# Loss: 0.5298988819122314
# Accuracy: 0.8420087695121765

# %% [markdown]
# ## Plotting Predictions

# %%
def plot_predictions(generator, model):
    # Retrieve a batch of images and true labels from the generator
    images, true_labels = next(iter(generator))

    # Extract class names from the generator
    digits = [str(i) for i in range(10)]
    uppercase = [i for i in string.ascii_uppercase]
    lowercase = [i for i in string.ascii_lowercase]
    class_names = digits + uppercase + lowercase

    # Convert TensorFlow tensors to NumPy arrays if necessary
    if isinstance(true_labels, tensorflow.Tensor):
        true_labels = true_labels.numpy()
    if isinstance(images, tensorflow.Tensor):
        images = images.numpy()

    # Convert true_labels to class indices if they are one-hot encoded
    if true_labels.ndim > 1 and true_labels.shape[1] > 1:
        true_labels = np.argmax(true_labels, axis=1)

    # Ensure true_labels are integers
    true_labels = true_labels.astype(int)

    # Make predictions on the batch of images
    predictions = model.predict(images)
    predicted_classes = np.argmax(predictions, axis=1).astype(int)

    # Check dimensions and types
    print(f'Images shape: {images.shape}')
    print(f'True labels shape: {true_labels.shape}, dtype: {true_labels.dtype}')
    print(f'Predicted classes shape: {predicted_classes.shape}, dtype: {predicted_classes.dtype}')

    # Set up the plot
    num_images = len(images)
    print(f'Number of images: {num_images}')

    # Calculate the number of rows needed
    num_cols = 6
    num_rows = int(np.ceil(num_images / num_cols))

    # Create subplots
    fig, axes = plt.subplots(nrows=num_rows, ncols=num_cols, figsize=(20, 5 * num_rows))

    # Flatten axes array for easy iteration
    axes = axes.flatten()

    for i in range(num_images):
        ax = axes[i]
        img = images[i]
        true_label_index = true_labels[i]
        predicted_label_index = predicted_classes[i]

        # Rescale the image if it was scaled during preprocessing
        img = img.astype(np.uint8)

        # Plot the image
        ax.imshow(img)
        ax.axis('off')

        # Get class names
        true_label_name = class_names[true_label_index]
        predicted_label_name = class_names[predicted_label_index]

        # Display true and predicted class names as text
        ax.set_title(f'True: {true_label_name}\nPred: {predicted_label_name}')

    # Hide any unused subplots
    for j in range(num_images, len(axes)):
        axes[j].axis('off')

    plt.tight_layout()
    plt.show()

# %%
plot_predictions(val_ds_norm, model)
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step
# Images shape: (32, 224, 224, 3)
# True labels shape: (32,), dtype: int64
# Predicted classes shape: (32,), dtype: int64
# Number of images: 32

# %%
plot_predictions(test_ds, model)
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step
# Images shape: (32, 224, 224, 3)
# True labels shape: (32,), dtype: int64
# Predicted classes shape: (32,), dtype: int64
# Number of images: 32

# %%
plot_predictions(train_ds, model)
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step
# Images shape: (32, 224, 224, 3)
# True labels shape: (32,), dtype: int64
# Predicted classes shape: (32,), dtype: int64
# Number of images: 32

# %%
y_true = []
y_pred = []

for images, labels in test_ds:
    preds = model.predict(images)
    y_true.extend(labels.numpy())
    y_pred.extend(np.argmax(preds, axis=1))

y_true = np.array(y_true)
y_pred = np.array(y_pred)
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step

# %% [markdown]
# ## Confusion Matrix

# %%
cm = confusion_matrix(y_true, y_pred)

# %%
digits = [str(i) for i in range(10)]
uppercase = [i for i in string.ascii_uppercase]
lowercase = [i for i in string.ascii_lowercase]
class_names = digits + uppercase + lowercase
num_classes = len(np.unique(y_true))
cm_df = pd.DataFrame(cm, index=class_names, columns=class_names)

plt.figure(figsize=(20, 20))
sns.heatmap(cm_df, annot=True, fmt='d', cmap='Blues', cbar=True, square=True,
            xticklabels=class_names, yticklabels=class_names)
plt.xlabel('Predicted Labels')
plt.ylabel('True Labels')
plt.title('Confusion Matrix')
plt.show()

# %% [markdown]
# ## Saving Model

# %%
model.save('model.keras')
